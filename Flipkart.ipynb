# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
import logging

# %%
product="iphone13"

# %%
flipkart_url="https://www.flipkart.com/search?q="+product

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone13'

# %%
urlClient=urlopen(flipkart_url)

# %%
#urlClient.read()

# %%
flipkart_page=urlClient.read()

# %%
flipkart_html=bs(flipkart_page,"html.parser")

# %%
#flipkart_html

# %%
bigbox=flipkart_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 31

# %%
#bigbox[24] #by using hit and try method i identy that from which range product box are

# %%
#del bigbox[24:]

# %%
product_href_link=bigbox[3].div.div.div.a['href']

# %%
#del bigbox[:3]

# %%
for i in bigbox:
    try:
        print(i.div.div.div.a['href'])
    except Exception as e:
        print(e)
# Out:
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object has no attribute 'div'
# /apple-iphone-13-starlight-128-gb/p/itmc9604f122ae7f?pid=MOBG6VF5ADKHKXFX&lid=LSTMOBG6VF5ADKHKXFXQGX7PK&marketplace=FLIPKART&q=iphone13&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=70345edd-85a1-4337-b1f5-8b765558cea3.MOBG6VF5ADKHKXFX.SEARCH&ppt=None&ppn=None&ssid=w8jdydws4w0000001689963609315&qH=7d4afaedfc628b80
# /apple-iphone-13-midnight-128-gb/p/itmca361aab1c5b0?pid=MOBG6VF5Q82T3XRS&lid=LSTMOBG6VF5Q82T3XRSOXJLM9&marketplace=FLIPKART&q=iphone13&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=70345edd-85a1-4337-b1f5-8b765558cea3.MOBG6VF5Q82T3XRS.SEARCH&ppt=None&ppn=None&ssid=w8jdydws4w0000001689963609315&qH=7d4afaedfc628b80
# ...

# %%
product_link="https://www.flipkart.com"+product_href_link

# %%
product_link
# Out:
# 'https://www.flipkart.com/apple-iphone-13-starlight-128-gb/p/itmc9604f122ae7f?pid=MOBG6VF5ADKHKXFX&lid=LSTMOBG6VF5ADKHKXFXQGX7PK&marketplace=FLIPKART&q=iphone13&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=70345edd-85a1-4337-b1f5-8b765558cea3.MOBG6VF5ADKHKXFX.SEARCH&ppt=None&ppn=None&ssid=w8jdydws4w0000001689963609315&qH=7d4afaedfc628b80'

# %%
product_req=requests.get(product_link)

# %%
product_req
# Out:
# <Response [200]>

# %%
product_html=bs(product_req.text,"html.parser")

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
comment_box=product_html.find_all("div",{"class":"_16PBlm"})

# %%
comment_box[0]
# Out:
# <div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Nice product</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Best phone for day to day use and photography/videography.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_e59eeff69669474fa0c812e1487d7f6f.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_06f4a16c6ba54659b1711f21a42d76ee.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_ad1051358b6848f38
# ...

# %%
#comment_box[7]

# %%
product_Caption=comment_box[0].div.div.div.p.text

# %%
product_Caption
# Out:
# 'Nice product'

# %%
product_rating=comment_box[0].div.div.div.div.text

# %%
product_rating
# Out:
# '4'

# %%
product_Discription=comment_box[0].div.div.find("div",{"class":""}).div.text

# %%
product_Discription
# Out:
# 'Best phone for day to day use and photography/videography.'

# %%
for i in comment_box:
    try:
        print("Product_rating:",i.div.div.div.div.text)
        print("Product_Caption:",i.div.div.div.p.text)
        print("Product_Discription:",i.div.div.find("div",{"class":""}).div.text)
        print()
    except Exception as e:
        print(e)
# Out:
# Product_rating: 4
# Product_Caption: Nice product
# Product_Discription: Best phone for day to day use and photography/videography.
#
# Product_rating: 5
# Product_Caption: Fabulous!
# Product_Discription: Nice product
#
# Product_rating: 5
# Product_Caption: Perfect product!
# Product_Discription: Love this phone..... 😍
#
# Product_rating: 5
# Product_Caption: Terrific
# Product_Discription: Happy to have this phone
#
# Product_rating: 5
# Product_Caption: Best in the market!
# Product_Discription: Best phone available at this price point.Camera is comparable with entry level DSLR(marvellous dynamic range)The performance is unmatchable.Shifted to iOS after 10 years of premium android smartphones.Go  for it without any second thought.
#
# Product_rating: 5
# Product_Caption: Just wow!
# Product_Discription: Best phone in recent times I have used in my life
#
# Product_rating: 5
# Product_Caption: Wonderful
# Product_Discription: Just amazing
#
# Product_rating: 5
# ...

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[10]
# Out:
# <div class="_3UAT2v _16PBlm"><span class="">All 1604 reviews</span></div>
